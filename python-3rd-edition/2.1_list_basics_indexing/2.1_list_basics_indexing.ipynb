# %% [markdown]
# # List Basics and Indexing
#
# This Jupyter notebook provides an interactive environment for learning about list basics and indexing in Python.
#
# ## Instructions
# 1. Follow the TODO comments in the code cells
# 2. Run each cell to see the output
# 3. Use the test cells to verify your implementation
#
# ## Learning Objectives
# This exercise will help you learn:
# - How to create lists in Python
# - How to access list elements using indexing
# - How to use negative indexing
# - How to slice lists to get sublists
# - How to find the length of a list
# - Basic list operations and methods
#
# ## Requirements
# - Use square brackets `[]` to create lists
# - Access elements using zero-based indexing
# - Use negative indices to access elements from the end
# - Apply slicing with `[:]` syntax
# - Use `len()` function to get list length
# - Understand that indexing starts at 0 in Python

# %%
# TODO 1: Create a list named 'fruits' with at least 5 different fruit names as strings
# fruits = 

# TODO 2: Create a list named 'numbers' with at least 5 different integers
# numbers = 

# TODO 3: Create a list named 'mixed' with different data types (string, int, float, bool)
# mixed = 

# Print your lists to see their contents
print("Fruits:", fruits)
print("Numbers:", numbers)
print("Mixed:", mixed)

# %%
# TODO 4: Access and print the first element of the 'fruits' list
# first_fruit = 

# TODO 5: Access and print the last element of the 'numbers' list using negative indexing
# last_number = 

# TODO 6: Access and print the second element of the 'mixed' list
# second_mixed = 

# Print your accessed elements
print("First fruit:", first_fruit)
print("Last number:", last_number)
print("Second mixed element:", second_mixed)

# %%
# TODO 7: Use slicing to get the first three elements of the 'fruits' list
# first_three_fruits = 

# TODO 8: Use slicing to get the last two elements of the 'numbers' list
# last_two_numbers = 

# TODO 9: Use slicing to get elements from index 1 to 3 (not including 3) from the 'mixed' list
# middle_mixed = 

# Print your sliced lists
print("First three fruits:", first_three_fruits)
print("Last two numbers:", last_two_numbers)
print("Middle mixed elements:", middle_mixed)

# %%
# TODO 10: Find and print the length of each list using the len() function
# fruits_length = 
# numbers_length = 
# mixed_length = 

# Print the lengths
print("Fruits list length:", fruits_length)
print("Numbers list length:", numbers_length)
print("Mixed list length:", mixed_length)

# TODO 11: Try to access an element that doesn't exist (e.g., index 10 in fruits list)
# What happens when you run this code? (This will cause an IndexError - comment out after testing)
# non_existent = fruits[10]

# %% [markdown]
# ## Testing Your Code
#
# You can test your code in multiple ways:
#
# 1. **Interactive testing**: Run code cells and observe outputs
# 2. **Pytest**: Run the test_exercise.py file

# %%
# Run pytest tests
import subprocess
import sys

try:
    result = subprocess.run([sys.executable, '-m', 'pytest', 'test_exercise.py', '-v'], 
                          capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print("Errors:", result.stderr)
except Exception as e:
    print(f"Error running pytest: {e}")
