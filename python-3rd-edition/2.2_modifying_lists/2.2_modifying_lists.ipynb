# %% [markdown]
# # Modifying Lists
#
# This Jupyter notebook provides an interactive environment for learning about modifying lists in Python.
#
# ## Instructions
# 1. Follow the TODO comments in the code cells
# 2. Run each cell to see the output
# 3. Use the test cells to verify your implementation
#
# ## Learning Objectives
# This exercise will help you learn:
# - How to modify list elements by index
# - How to add elements to lists using append(), insert(), and extend()
# - How to remove elements from lists using remove(), pop(), and del
# - How to sort lists using sort() and sorted()
# - How to reverse lists using reverse()
# - How to copy lists and avoid common pitfalls
#
# ## Requirements
# - Use indexing to modify specific list elements
# - Apply list methods like append(), insert(), extend()
# - Use remove(), pop(), and del to remove elements
# - Sort lists with sort() and sorted()
# - Reverse lists with reverse()
# - Understand the difference between shallow and deep copying

# %%
# TODO 1: Create a list named 'colors' with at least 4 color names as strings
# colors = 

# TODO 2: Modify the first element of the 'colors' list to a different color
# colors[0] = 

# Print the list to see the modification
print("Colors after modification:", colors)

# %%
# TODO 3: Add a new color to the end of the 'colors' list using append()
# colors.append()

# TODO 4: Insert a new color at index 2 of the 'colors' list using insert()
# colors.insert()

# Print the list to see the additions
print("Colors after additions:", colors)

# %%
# TODO 5: Create another list named 'more_colors' with 2 additional colors
# more_colors = 

# TODO 6: Add all elements from 'more_colors' to 'colors' using extend()
# colors.extend()

# Print both lists
print("More colors:", more_colors)
print("Colors after extending:", colors)

# %%
# TODO 7: Remove a specific color from the 'colors' list using remove()
# colors.remove()

# TODO 8: Remove and return the last element from the 'colors' list using pop()
# last_color = colors.pop()

# TODO 9: Remove the first element from the 'colors' list using del
# del colors[0]

# Print the results
print("Colors after removals:", colors)
print("Last color popped:", last_color)

# %%
# TODO 10: Sort the 'colors' list alphabetically using sort()
# colors.sort()

# TODO 11: Create a sorted copy of the 'colors' list without modifying the original using sorted()
# sorted_colors = sorted(colors)

# TODO 12: Reverse the order of the 'colors' list using reverse()
# colors.reverse()

# Print the results
print("Colors after sorting:", colors)
print("Sorted copy:", sorted_colors)
print("Colors after reversing:", colors)

# %%
# TODO 13: Create a copy of the 'colors' list using the copy() method
# colors_copy = colors.copy()

# TODO 14: Try to create a copy by assignment (this creates a reference, not a copy)
# colors_reference = colors
# Modify colors_reference and observe what happens to colors
# colors_reference.append("brown")

# Print both lists to see the difference
print("Colors copy:", colors_copy)
print("Colors reference:", colors_reference)
print("Original colors:", colors)

# %% [markdown]
# ## Testing Your Code
#
# You can test your code in multiple ways:
#
# 1. **Interactive testing**: Run code cells and observe outputs
# 2. **Pytest**: Run the test_exercise.py file

# %%
# Run pytest tests
import subprocess
import sys

try:
    result = subprocess.run([sys.executable, '-m', 'pytest', 'test_exercise.py', '-v'], 
                          capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print("Errors:", result.stderr)
except Exception as e:
    print(f"Error running pytest: {e}")
