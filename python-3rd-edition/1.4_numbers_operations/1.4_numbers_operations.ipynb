# %% [markdown]
# # Python Exercise Template
#
# This Jupyter notebook provides an interactive environment for completing the Python exercise.
#
# ## Instructions
# 1. Follow the TODO comments in the code cells
# 2. Run each cell to see the output
# 3. Use the test cells to verify your implementation
#
# ## Learning Objectives
# This exercise will help you learn:
# - [Exercise-specific learning objectives]
#
# ## Requirements
# - [Exercise-specific requirements]

# %%
# TODO: Add your exercise code here
# This cell corresponds to the exercise.py file

# Add your implementation based on the exercise requirements
print("Hello, Python exercise!")

# %% [markdown]
# ## Testing Your Code
#
# You can test your code in multiple ways:
#
# 1. **Interactive testing**: Run code cells and observe outputs
# 2. **Unittest**: Run the test_exercise.py file
# 3. **Pytest**: Run the test_exercise_pytest.py file

# %%
# Run unittest tests
import subprocess
import sys

try:
    result = subprocess.run([sys.executable, '-m', 'unittest', 'test_exercise.py', '-v'], 
                          capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print("Errors:", result.stderr)
except Exception as e:
    print(f"Error running unittest: {e}")

# %%
# Run pytest tests
try:
    result = subprocess.run([sys.executable, '-m', 'pytest', 'test_exercise_pytest.py', '-v'], 
                          capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print("Errors:", result.stderr)
except Exception as e:
    print(f"Error running pytest: {e}")
